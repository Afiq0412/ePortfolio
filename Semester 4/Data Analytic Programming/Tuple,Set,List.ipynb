# %%
tup = 1, 2, 3
tup

# %%
tup1 = 'abc',
tup1

# %%
a, b, c = 7,8,9

print(a)
print(b)
print(c)
print(type(a))

# %%
test = 1,2,3
print(test)
type(test)

# %%
nested_tuple = (4,5,6), (7,8)

nested_tuple

# %%
x = tuple([4,0,2])
y = 4,0,2

print(x)
print(type(x))
print(y)
print(type(y))

# %%
tup1 = tuple(['hello']) #convert list to tuple
print(tup1)
print(type(tup1))

tup2 = ('hello', )
print(tup2)
print(type(tup2))
# Out:
# ('hello',)
# <class 'tuple'>
# ('hello',)
# <class 'tuple'>

# %%
list_of_objects = [1,2,3,4,5]
print(list_of_objects)
print(type(list_of_objects))

list_1 = tuple(list_of_objects)
print(list_1)
print(type(list_1))

# %%
tup1 = tuple('python')
print(tup1)
print(type(tup1))

tup1[0]
# Out:
# ('p', 'y', 't', 'h', 'o', 'n')
# <class 'tuple'>
# 'p'

# %%
tup = tuple(['aishah', [1,2,3], True])
print(tup)

tup[1].append(3)
tup
# Out:
# ('aishah', [1, 2, 3], True)
# ('aishah', [1, 2, 3, 3], True)

# %%
print(tup)
print(tup1)
# Out:
# ('aishah', [1, 2, 3, 3], True)
# ('p', 'y', 't', 'h', 'o', 'n')

# %%
print()
add_tup = tup + tup1
print(add_tup)
print(type(add_tup))
# Out:
# ('aishah', [1, 2, 3, 3], True, 'p', 'y', 't', 'h', 'o', 'n')
# <class 'tuple'>

# %%
('aishah', 'aiman')*2
# Out:
# ('aishah', 'aiman', 'aishah', 'aiman')

# %%
tup = (4,5,6)

a,b,c = tup

print(a)
print(b)
print(c)

for t in tup:
    print(t)
# Out:
# 4
# 5
# 6
# 4
# 5
# 6

# %%
tup = 4,5,(6,7)
print(tup)

a,b,(c,d) = tup

print(c,d)
# Out:
# (4, 5, (6, 7))
# 6 7

# %%
a,b = 1,2
print('a =', a)
print('b =', b)

b,a = a,b
print('after swapping')
print('a =', a)
print('b =', b)
# Out:
# a = 1
# b = 2
# after swapping
# a = 2
# b = 1

# %%
seq = [(1,2,3),(4,5,6),(7,8,9)]
print(type(seq))

for a,b,c in seq:
    print('a={0},b={1},c={2}'.format(a,b,c))
    print(a)
    print(b)
    print(c)
# Out:
# <class 'list'>
# a=1,b=2,c=3
# 1
# 2
# 3
# a=4,b=5,c=6
# 4
# 5
# 6
# a=7,b=8,c=9
# 7
# 8
# 9

# %%
tup = (5,1,[7,8],3,'Python','Java','C++')
print(tup)
A,C,D, *rest = tup
print(A)
print(*rest)
print(C)
print(D)

# %%
a = (1,2,2,2,2,2,2,2,2,2,2,3,4)

a.count(2)
# Out:
# 10

# %%
# LIST
a_list = [2,3,7, None]
tup = ('aiman', 'foo', 'david')

print(a_list)
print(type(a_list))
print(type(tup))

b_list = list(tup)
print(b_list)
print(type(b_list))
# Out:
# [2, 3, 7, None]
# <class 'list'>
# <class 'tuple'>
# ['aiman', 'foo', 'david']
# <class 'list'>

# %%
b_list
# Out:
# ['aiman', 'foo', 'david']

# %%
b_list[1] = 'amirah'

b_list
# Out:
# ['aiman', 'amirah', 'david']

# %%
b = a = [1,2,3,5,6]
a.append(0)
a = [4,5]
print(b)
print(a)
# Out:
# [1, 2, 3, 5, 6, 0]
# [4, 5]

# %%
gen = range(5)
print(type(gen))
print(gen)

c_list = list(gen)
print(type(c_list))
print(c_list)
# Out:
# <class 'range'>
# range(0, 5)
# <class 'list'>
# [0, 1, 2, 3, 4]
